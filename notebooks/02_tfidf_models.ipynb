# %% [markdown]
# # Importando as Bibliotecas

# %%
import pandas as pd
import re

print("Bibliotecas Salvas com Sucesso!!")
# Out:
# Bibliotecas Salvas com Sucesso!!

# %% [markdown]
# # Leitura da Base de Dados

# %%
dados = pd.read_csv("../data/dataset_tratado.csv", index_col=0)
dados.head()
# Out:
#                                review_comment_message  review_score sentimento
# 3               Recebi bem antes do prazo estipulado.             5   positivo
# 4   Parabéns lojas lannister adorei comprar pela I...             5   positivo
# 9   aparelho eficiente. no site a marca do aparelh...             4   positivo
# 12    Mas um pouco ,travando...pelo valor ta Boa.\r\n             4   positivo
# 15  Vendedor confiável, produto ok e entrega antes...             5   positivo

# %% [markdown]
# # 1. Pré-Processamento

# %% [markdown]
# ## Limpando o Texto

# %%
CONTRACTIONS = {
    'vc': 'você', 'tb': 'também', 'tbm': 'também', 'pq': 'por que', 'obg': 'obrigado', 'blz': 'beleza',
    'td': 'tudo', 'msm': 'mesmo', 'vlw': 'valeu', 'n': 'não', 'naum': 'não', 'cmprar': 'comprar',
    'mt': 'muito', 'pra': 'para'
}

# %%
def limpar_texto(texto):

    # 1. Lowercase
    texto = texto.lower()
    # 2. Remove HTML
    texto = re.sub(r'<[^>]+>', ' ', texto)
    # 3. Remove URLs
    texto = re.sub(r'http\S+|www\.\S+', ' ', texto)
    # 4. Remove e-mails
    texto = re.sub(r'\S+@\S+', ' ', texto)
    # 5. Expande contrações
    # Primeiro quebra o texto em palavras (texto.split())
    # Depois troca as contrações no dicionário (CONTRACTIONS)
    # Por fim junta tudo
    palavras = [CONTRACTIONS.get(p,p) for p in texto.split()]
    texto = ' '.join(palavras)

    # 6. Remove caracteres indesejados
    texto = re.sub(r'[^a-záàâãéêèíìîóôõöúùûüç\s.,!?]', ' ', texto)

    # 7. Normaliza espaços
    texto = re.sub(r'\s+', ' ', texto).strip()

    return texto

# %%
# Fazendo um teste da função
teste = "<p>ADOREI o produto!!! vc precisa comprar tbm https://loja.com</p>"
resultado = limpar_texto(teste)
print(resultado)
# Out:
# adorei o produto!!! você precisa comprar também

# %%
dados['texto_limpo'] = dados['review_comment_message'].apply(limpar_texto)
dados.head()
# Out:
#                                review_comment_message  review_score  \
# 3               Recebi bem antes do prazo estipulado.             5
# 4   Parabéns lojas lannister adorei comprar pela I...             5
# 9   aparelho eficiente. no site a marca do aparelh...             4
# 12    Mas um pouco ,travando...pelo valor ta Boa.\r\n             4
# 15  Vendedor confiável, produto ok e entrega antes...             5
#
#    sentimento                                        texto_limpo
# 3    positivo              recebi bem antes do prazo estipulado.
# 4    positivo  parabéns lojas lannister adorei comprar pela i...
# 9    positivo  aparelho eficiente. no site a marca do aparelh...
# 12   positivo        mas um pouco ,travando...pelo valor ta boa.
# 15   positivo  vendedor confiável, produto ok e entrega antes...

# %% [markdown]
# ## Tokenização - Quebrando texto em unidades

# %%
import nltk
from nltk.corpus import stopwords

nltk.download("punkt", quiet=True)
nltk.download("punkt_tab", quiet=True)
nltk.download("stopwords", quiet=True)

from nltk.tokenize import word_tokenize

# %%
STOP_WORDS_PT = set(stopwords.words('portuguese'))

NEGACOES = {"não", "nao", "nunca", "nem", "sem"}

STOP_WORDS_PT = STOP_WORDS_PT - NEGACOES

# %%
modelo = "Eu sou cientista de dados"

tokens = word_tokenize(modelo, language="portuguese")
print(tokens)
# Out:
# ['Eu', 'sou', 'cientista', 'de', 'dados']

# %%
def tokenizacao(texto):

    return word_tokenize(texto, language="portuguese")

# %%
dados["tokens"] = dados["texto_limpo"].apply(tokenizacao)

dados[["texto_limpo", "tokens"]].head()
# Out:
#                                           texto_limpo  \
# 3               recebi bem antes do prazo estipulado.
# 4   parabéns lojas lannister adorei comprar pela i...
# 9   aparelho eficiente. no site a marca do aparelh...
# 12        mas um pouco ,travando...pelo valor ta boa.
# 15  vendedor confiável, produto ok e entrega antes...
#
#                                                tokens
# 3      [recebi, bem, antes, do, prazo, estipulado, .]
# 4   [parabéns, lojas, lannister, adorei, comprar, ...
# 9   [aparelho, eficiente, ., no, site, a, marca, d...
# 12  [mas, um, pouco, ,, travando, ..., pelo, valor...
# 15  [vendedor, confiável, ,, produto, ok, e, entre...

# %%
def remover_stop_words(tokens):
    resultado = []

    for token in tokens:
        if(
            token.isalpha() and token not in STOP_WORDS_PT
        ):
            resultado.append(token)
    return resultado

# %%
dados["tokens"] = dados["tokens"].apply(remover_stop_words)

dados[["texto_limpo", "tokens"]].head()
# Out:
#                                           texto_limpo  \
# 3               recebi bem antes do prazo estipulado.
# 4   parabéns lojas lannister adorei comprar pela i...
# 9   aparelho eficiente. no site a marca do aparelh...
# 12        mas um pouco ,travando...pelo valor ta boa.
# 15  vendedor confiável, produto ok e entrega antes...
#
#                                                tokens
# 3             [recebi, bem, antes, prazo, estipulado]
# 4   [parabéns, lojas, lannister, adorei, comprar, ...
# 9   [aparelho, eficiente, site, marca, aparelho, i...
# 12                  [pouco, travando, valor, ta, boa]
# 15  [vendedor, confiável, produto, ok, entrega, an...

# %% [markdown]
# ## Stemming - Reduzindo palavras ao seu radical

# %%
from nltk.stem import RSLPStemmer
import nltk
nltk.download("rslp", quiet=True)
# Out:
# True

# %%
# exemplo
texto = ['correndo', 'correu', 'estudou', 'participou', 'ganhou']

stemmer_rslp = RSLPStemmer()
for palavras in texto:
    print(stemmer_rslp.stem(palavras))
# Out:
# corr
# corr
# estud
# particip
# ganh

# %%
def aplicar_stemming(tokens):
    resultado = []

    for token in tokens:
        resultado.append(stemmer_rslp.stem(token))

    return resultado

# %%
dados["stemmer"] = dados["tokens"].apply(aplicar_stemming)

dados[["texto_limpo", "tokens", "stemmer"]].head()
# Out:
#                                           texto_limpo  \
# 3               recebi bem antes do prazo estipulado.
# 4   parabéns lojas lannister adorei comprar pela i...
# 9   aparelho eficiente. no site a marca do aparelh...
# 12        mas um pouco ,travando...pelo valor ta boa.
# 15  vendedor confiável, produto ok e entrega antes...
#
#                                                tokens  \
# 3             [recebi, bem, antes, prazo, estipulado]
# 4   [parabéns, lojas, lannister, adorei, comprar, ...
# 9   [aparelho, eficiente, site, marca, aparelho, i...
# 12                  [pouco, travando, valor, ta, boa]
# 15  [vendedor, confiável, produto, ok, entrega, an...
#
#                                               stemmer
# 3                    [receb, bem, ant, praz, estipul]
# 4   [parabém, loj, lannist, ador, compr, internet,...
# 9   [aparelh, efici, sit, marc, aparelh, impress, ...
# 12                         [pouc, trav, val, ta, boa]
# 15       [vend, confi, produt, ok, entreg, ant, praz]

# %%
def juntar_palavras(textos):

    return " ".join(textos)

# %%
dados["dados_juntos"] = dados["stemmer"].apply(juntar_palavras)

dados[["stemmer", "dados_juntos"]].head()
# Out:
#                                               stemmer  \
# 3                    [receb, bem, ant, praz, estipul]
# 4   [parabém, loj, lannist, ador, compr, internet,...
# 9   [aparelh, efici, sit, marc, aparelh, impress, ...
# 12                         [pouc, trav, val, ta, boa]
# 15       [vend, confi, produt, ok, entreg, ant, praz]
#
#                                          dados_juntos
# 3                          receb bem ant praz estipul
# 4   parabém loj lannist ador compr internet segur ...
# 9   aparelh efici sit marc aparelh impress desinfe...
# 12                               pouc trav val ta boa
# 15               vend confi produt ok entreg ant praz

# %% [markdown]
# ## Pipeline Completo

# %%
def pipeline_tratamento(texto):
        
    texto = limpar_texto(texto)
    texto_tokenizado = tokenizacao(texto)
    texto_sem_stop_word = remover_stop_words(texto_tokenizado)
    texto_stemme = aplicar_stemming(texto_sem_stop_word)
    resultado = juntar_palavras(texto_stemme)

    return resultado

# %%
df_pipeline = dados[["review_comment_message", "sentimento"]].copy()
df_pipeline.head()
# Out:
#                                review_comment_message sentimento
# 3               Recebi bem antes do prazo estipulado.   positivo
# 4   Parabéns lojas lannister adorei comprar pela I...   positivo
# 9   aparelho eficiente. no site a marca do aparelh...   positivo
# 12    Mas um pouco ,travando...pelo valor ta Boa.\r\n   positivo
# 15  Vendedor confiável, produto ok e entrega antes...   positivo

# %%
df_pipeline["review_tratado"] = df_pipeline["review_comment_message"].apply(pipeline_tratamento)
df_pipeline[["review_comment_message", "review_tratado"]].head()
# Out:
#                                review_comment_message  \
# 3               Recebi bem antes do prazo estipulado.
# 4   Parabéns lojas lannister adorei comprar pela I...
# 9   aparelho eficiente. no site a marca do aparelh...
# 12    Mas um pouco ,travando...pelo valor ta Boa.\r\n
# 15  Vendedor confiável, produto ok e entrega antes...
#
#                                        review_tratado
# 3                          receb bem ant praz estipul
# 4   parabém loj lannist ador compr internet segur ...
# 9   aparelh efici sit marc aparelh impress desinfe...
# 12                               pouc trav val ta boa
# 15               vend confi produt ok entreg ant praz

# %% [markdown]
# # 2. Vetorizando Texto

# %% [markdown]
# ## Divisão do Treinamento

# %%
from sklearn.model_selection import train_test_split

# %%
sentimento = {
    "positivo": 1,
    "negativo": 0
}
df_pipeline["sentimento"] = df_pipeline["sentimento"].map(sentimento)

print("Dados únicos do sentimento")
print(df_pipeline["sentimento"].unique())
# Out:
# Dados únicos do sentimento
# [1 0]

# %%
X = df_pipeline["review_tratado"]
y = df_pipeline["sentimento"]

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, stratify=y, random_state=42, test_size=0.3)

print(f"Dados Treino -> {len(X_treino)}")
print(f"Dados Teste -> {len(X_teste)}")
# Out:
# Dados Treino -> 26194
# Dados Teste -> 11226

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(
    lowercase=True,
    ngram_range=(1,2),
    min_df=5,
    max_df=0.85,
    max_features=10000,
    sublinear_tf=True
)

# %%
X_tfidf = vectorizer.fit_transform(X_treino)
print(X_tfidf.shape)
# Out:
# (26194, 5755)

# %%
feature_names = vectorizer.get_feature_names_out()

print(f"Quantidade de features: {len(feature_names)}")
print(feature_names[:50])
# Out:
# Quantidade de features: 5755
# ['ab' 'abaix' 'abajur' 'abenço' 'abert' 'aborrec' 'abr' 'abr caix'
#  'abr embal' 'abr produt' 'abr reclam' 'abraç' 'abril' 'absurd' 'acab'
#  'acab bem' 'acab boa' 'acab bom' 'acab cheg' 'acab compr' 'acab entreg'
#  'acab não' 'acab perfeit' 'acab produt' 'acab receb' 'acab recom'
#  'acab ruim' 'aceit' 'acend' 'acert' 'acess' 'acessóri' 'ach' 'ach absurd'
#  'ach bem' 'ach bom' 'ach car' 'ach demor' 'ach dev' 'ach entreg'
#  'ach falt' 'ach fret' 'ach loj' 'ach mater' 'ach melhor' 'ach não'
#  'ach pequen' 'ach pod' 'ach pouc' 'ach produt']

# %%
import numpy as np

feature_names = vectorizer.get_feature_names_out()

doc = X_tfidf[0].toarray().flatten()

top_idx = np.argsort(doc)[-10:][::-1]

for i in top_idx:
    if doc[i] > 0:
        print(f"{feature_names[i]:20} {doc[i]:.3f}")
# Out:
# med não              0.336
# fiq med              0.331
# compr fiq            0.320
# ia                   0.300
# env                  0.295
# devolv dinh          0.285
# faz compr            0.280
# med                  0.245
# dinh                 0.210
# devolv               0.210

# %% [markdown]
# # 3. Modelos de NLP

# %%
from sklearn.model_selection import (
    RandomizedSearchCV,
    GridSearchCV,
    StratifiedKFold
)

from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC

from sklearn.pipeline import Pipeline

from sklearn.metrics import (
    classification_report,
    ConfusionMatrixDisplay
)

import matplotlib.pyplot as plt

# %% [markdown]
# ## Modelo Naive Bayes

# %%
pipeline_nb = Pipeline([
    ('tfidf', vectorizer),
    ('modelo_nb', MultinomialNB(alpha=1.0))
])

# %%
pipeline_nb.fit(X_treino, y_treino)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.85, max_features=10000, min_df=5,
#                                  ngram_range=(1, 2), sublinear_tf=True)),
#                 ('modelo_nb', MultinomialNB())])

# %%
previsao_nb = pipeline_nb.predict(X_teste)

print("=== Resultados Modelo Naive Bayes ===")
print(classification_report(y_teste, previsao_nb))
# Out:
# === Resultados Modelo Naive Bayes ===
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88      3267
#            1       0.96      0.94      0.95      7959
#
#     accuracy                           0.93     11226
#    macro avg       0.91      0.92      0.92     11226
# weighted avg       0.93      0.93      0.93     11226

# %%
ConfusionMatrixDisplay.from_estimator(pipeline_nb, X_teste, y_teste, cmap="Reds")
plt.title("Matriz de Confusão - Naive Bayes")
plt.show()

# %% [markdown]
# ## Modelo Regressão Logística

# %%
pipeline_rl = Pipeline([
    ("tfidf", vectorizer),
    ("modelo_rl", LogisticRegression(max_iter=2000, class_weight="balanced", random_state=42))
])

# %%
pipeline_rl.fit(X_treino, y_treino)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.85, max_features=10000, min_df=5,
#                                  ngram_range=(1, 2), sublinear_tf=True)),
#                 ('modelo_rl',
#                  LogisticRegression(class_weight='balanced', max_iter=2000,
#                                     random_state=42))])

# %%
previsao_rl = pipeline_rl.predict(X_teste)

print("=== Resultados Modelo Regressão Logística ===")
print(classification_report(y_teste, previsao_rl))
# Out:
# === Resultados Modelo Regressão Logística ===
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      3267
#            1       0.98      0.92      0.95      7959
#
#     accuracy                           0.93     11226
#    macro avg       0.91      0.93      0.92     11226
# weighted avg       0.94      0.93      0.93     11226

# %%
ConfusionMatrixDisplay.from_estimator(pipeline_rl, X_teste, y_teste, cmap="Blues")
plt.title("Matriz de Confusão - Regressão Logística")
plt.show()

# %% [markdown]
# ## Modelo SVM - Support Vector Machine

# %%
pipeline_svm = Pipeline([
    ("tfidf", vectorizer),
    ("modelo_svm", LinearSVC(class_weight="balanced", random_state=42))
])

# %%
pipeline_svm.fit(X_treino, y_treino)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.85, max_features=10000, min_df=5,
#                                  ngram_range=(1, 2), sublinear_tf=True)),
#                 ('modelo_svm',
#                  LinearSVC(class_weight='balanced', random_state=42))])

# %%
previsao_svm = pipeline_svm.predict(X_teste)

print("=== Resultados Modelo SVM ===")
print(classification_report(y_teste, previsao_svm))
# Out:
# === Resultados Modelo SVM ===
#               precision    recall  f1-score   support
#
#            0       0.85      0.92      0.88      3267
#            1       0.97      0.93      0.95      7959
#
#     accuracy                           0.93     11226
#    macro avg       0.91      0.93      0.92     11226
# weighted avg       0.93      0.93      0.93     11226

# %%
ConfusionMatrixDisplay.from_estimator(pipeline_svm, X_teste, y_teste, cmap="Greens")
plt.title("Matriz de Confusão - SVM")
plt.show()

# %% [markdown]
# # 4. Otimização Modelos GridSearch

# %%
from sklearn.model_selection import (
    GridSearchCV,
    StratifiedKFold
)

# %% [markdown]
# ## Otimização Modelo Naive Bayes

# %%
pipeline_nb = Pipeline([
    ('tfidf', vectorizer),
    ('modelo_nb', MultinomialNB())
])

param_grid_nb = {
    "modelo_nb__alpha": [0.1, 0.5, 1.0, 2.0],
    "modelo_nb__fit_prior": [True, False]
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

grid_nb = GridSearchCV(
    estimator=pipeline_nb,
    param_grid=param_grid_nb,
    cv=cv,
    scoring="f1_macro",
)

grid_nb.fit(X_treino, y_treino)

print(f"Melhore Score -> {grid_nb.best_score_}")
print(f"Melhores Hiperparâmetros -> {grid_nb.best_params_}")
# Out:
# Melhore Score -> 0.9110504984180092
# Melhores Hiperparâmetros -> {'modelo_nb__alpha': 0.5, 'modelo_nb__fit_prior': True}

# %% [markdown]
# ## Otimização Modelo Regressão Logística

# %%
pipeline_rl = Pipeline([
    ("tfidf", vectorizer),
    ("modelo_rl", LogisticRegression(random_state=42, class_weight="balanced"))
])

param_grid_rl = {
    "modelo_rl__C": [0.1, 0.5, 1.0],
    "modelo_rl__max_iter": [1000, 2000, 3000],
}

grid_rl = GridSearchCV(
    estimator=pipeline_rl,
    param_grid=param_grid_rl,
    cv=cv,
    scoring="f1_macro"
)

grid_rl.fit(X_treino, y_treino)

print(f"Melhor Score -> {grid_rl.best_score_}")
print(f"Melhores Hiperparâmetros -> {grid_rl.best_params_}")
# Out:
# Melhor Score -> 0.9122457465322953
# Melhores Hiperparâmetros -> {'modelo_rl__C': 1.0, 'modelo_rl__max_iter': 1000}

# %% [markdown]
# ## Otimização Modelo SVM

# %%
pipeline_svm = Pipeline([
    ("tfidf", vectorizer),
    ("modelo_svm", LinearSVC(random_state=42, class_weight="balanced"))
])

param_grid_svm = {
    "modelo_svm__C": [0.01, 0.1, 0.5, 1.0]
}

grid_svm = GridSearchCV(
    estimator=pipeline_svm,
    param_grid=param_grid_svm,
    cv=cv,
    scoring="f1_macro"
)

grid_svm.fit(X_treino, y_treino)

print(f"Melhor Score -> {grid_svm.best_score_}")
print(f"Melhores Hiperparâmetros -> {grid_svm.best_params_}")
# Out:
# Melhor Score -> 0.9131559567838152
# Melhores Hiperparâmetros -> {'modelo_svm__C': 0.5}

# %% [markdown]
# ## Analisando Resultados

# %%
modelos_otimizados = {
    "Naive Bayes Otimizado": grid_nb.best_estimator_,
    "Regressão Logistica Otimizado": grid_rl.best_estimator_,
    "SVM Otimizado": grid_svm.best_estimator_
}

for nome, modelo in modelos_otimizados.items():
    modelo.fit(X_treino, y_treino)
    previsao = modelo.predict(X_teste)

    print(f"Modelo -> {nome}")
    print(classification_report(y_teste, previsao))
    print('-'*60)
# Out:
# Modelo -> Naive Bayes Otimizado
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88      3267
#            1       0.96      0.93      0.95      7959
#
#     accuracy                           0.93     11226
#    macro avg       0.91      0.92      0.91     11226
# weighted avg       0.93      0.93      0.93     11226
#
# ------------------------------------------------------------
# Modelo -> Regressão Logistica Otimizado
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      3267
#            1       0.98      0.92      0.95      7959
#
#     accuracy                           0.93     11226
#    macro avg       0.91      0.93      0.92     11226
# weighted avg       0.94      0.93      0.93     11226
#
# ------------------------------------------------------------
# Modelo -> SVM Otimizado
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89      3267
#            1       0.97      0.93      0.95      7959
#
#     accuracy                           0.93     11226
#    macro avg       0.91      0.93      0.92     11226
# weighted avg       0.93      0.93      0.93     11226
#
# ------------------------------------------------------------

# %%
modelo_nb_otimizado = grid_nb.best_estimator_
modelo_rl_otimizado = grid_rl.best_estimator_
modelo_svm_otimizado = grid_svm.best_estimator_

# %%
fig, ax = plt.subplots(1, 3, figsize=(18,6))

ConfusionMatrixDisplay.from_estimator(modelo_nb_otimizado, X_teste, y_teste, cmap="Reds", ax=ax[0])
ax[0].set_title("Modelo Naive Bayes Otimizado")

ConfusionMatrixDisplay.from_estimator(modelo_rl_otimizado, X_teste, y_teste, cmap="Blues", ax=ax[1])
ax[1].set_title("Modelo Regressão Logística Otimizado")

ConfusionMatrixDisplay.from_estimator(modelo_svm_otimizado, X_teste, y_teste, cmap="Greens", ax=ax[2])
ax[2].set_title("Modelo SVM Otimizado")

plt.suptitle("Matriz de Confusão - Modelos Otimizados",fontsize=16, fontweight="bold")
plt.show()

# %% [markdown]
# # 5. Verificando Learning Curve

# %%
from sklearn.model_selection import learning_curve

# %%
train_sizes, train_scores, val_scores = learning_curve(
    estimator=modelo_svm_otimizado,
    X=X_treino,
    y=y_treino,
    cv=cv,
    train_sizes=np.linspace(0.1, 1.0, 10),
    scoring="f1_macro",
    n_jobs=-1
)

train_mean = train_scores.mean(axis=1)
train_std = train_scores.std(axis=1)

val_mean = val_scores.mean(axis=1)
val_std = val_scores.std(axis=1)

# %%
plt.figure(figsize=(12, 6))

# Curva de treino
plt.plot(train_sizes, train_mean, marker="o", color="steelblue", label="Treino")
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="steelblue", alpha=0.15)

# Curva de validação
plt.plot(train_sizes, val_mean, marker="o", color="darkorange", label="Validação")
plt.fill_between(train_sizes, val_mean - val_std, val_mean + val_std, color="darkorange", alpha=0.15)

plt.title("Curva de Aprendizado - SVM", fontsize=14)
plt.xlabel("Quantidade de exemplos de treino", fontsize=12)
plt.ylabel("F1 Macro", fontsize=12)
plt.legend()
plt.grid(True, linestyle="--", alpha=0.3)
plt.tight_layout()
plt.show()

# %%
gap_final = train_mean[-1] - val_mean[-1]

print(f"Valor Final Treino -> {train_mean[-1]:.2f}")
print(f"Valor Final Validação -> {val_mean[-1]:.2f}")
print(f"GAP Final -> {gap_final:.2f}")
# Out:
# Valor Final Treino -> 0.95
# Valor Final Validação -> 0.91
# GAP Final -> 0.03

# %% [markdown]
# # 6. Avaliação Final do Conjunto Teste

# %%
modelo_final = grid_svm.best_estimator_

previsao_final = modelo_final.predict(X_teste)

# %%
print("=== Avaliação Final do Modelo ===")
print(classification_report(y_teste, previsao_final))
# Out:
# === Avaliação Final do Modelo ===
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89      3267
#            1       0.97      0.93      0.95      7959
#
#     accuracy                           0.93     11226
#    macro avg       0.91      0.93      0.92     11226
# weighted avg       0.93      0.93      0.93     11226

# %%
ConfusionMatrixDisplay.from_predictions(y_teste, previsao_final, cmap="Blues")
plt.title("Matriz de Confusão - Modelo Final")
plt.show()
